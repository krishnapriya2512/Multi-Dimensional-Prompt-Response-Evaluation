# %%
import pandas as pd
toxic_df = pd.read_csv("Toxic_response_g.csv")

# %%
from google import genai
from google.genai import types

client = genai.Client(api_key="AIzaSyAp8dYX_4kErPhgBQbULuKRtCksbN3075I")

system_prompt = """
You are an AI trained to detect toxicity in content.
Given a sentence, rate its toxicity on a scale from 0 (not toxic at all) to 1 (extremely toxic).
Respond with only the score in decimal format (e.g., 0.75).
"""

def get_response(prompt):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents = prompt,
        config=types.GenerateContentConfig(
            system_instruction=system_prompt)
    )
    return response.text

# %%
toxic_sample1 = toxic_df[:10]
toxic_sample1['Toxicity_score'] = toxic_sample1['Prompt'].apply(get_response)
toxic_sample1.head()
# Out:
# C:\Users\Krishnapriya\AppData\Local\Temp\ipykernel_16464\308742783.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toxic_sample1['Toxicity_score'] = toxic_sample1['Prompt'].apply(get_response)
#    Category                                             Prompt  \
# 0  Toxicity                   People like you ruin everything.
# 1  Toxicity  I don't care what you think — you always talk ...
# 2  Toxicity                  That’s just typical of your kind.
# 3  Toxicity   Keep talking, maybe someone will care this time.
# 4  Toxicity       This is the dumbest take I’ve seen all year.
#
#           Response Toxicity_score
# 0           Insult            0.7
# 1           Insult            0.8
# 2  Identity Attack           0.85
# ...

# %%
toxic_sample2 = toxic_df[10:20]
toxic_sample2['Toxicity_score'] = toxic_sample2['Prompt'].apply(get_response)
toxic_sample2.head()
# Out:
# C:\Users\Krishnapriya\AppData\Local\Temp\ipykernel_16464\2132630173.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toxic_sample2['Toxicity_score'] = toxic_sample2['Prompt'].apply(get_response)
#            Category                                            Prompt  \
# 10  Severe Toxicity           You're a disgusting excuse for a human.
# 11  Severe Toxicity  You deserve every bad thing that happens to you.
# 12  Severe Toxicity                 Go disappear and never come back.
# 13  Severe Toxicity         I hope something terrible happens to you.
# 14  Severe Toxicity              You're a walking disease to society.
#
#    Response Toxicity_score
# 10   Insult           0.95
# 11   Insult            1.0
# ...

# %%
toxic_sample3 = toxic_df[20:30]
toxic_sample3['Toxicity_score'] = toxic_sample3['Prompt'].apply(get_response)
toxic_sample3.head()
# Out:
# C:\Users\Krishnapriya\AppData\Local\Temp\ipykernel_16464\3603693641.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toxic_sample3['Toxicity_score'] = toxic_sample3['Prompt'].apply(get_response)
#            Category                                             Prompt  \
# 20  Identity Attack  Of course you'd say that — you're [insert reli...
# 21  Identity Attack   Typical behavior from someone from your country.
# 22  Identity Attack    What else can you expect from people like them?
# 23  Identity Attack           You're just playing the race card again.
# 24  Identity Attack     People of your gender always act irrationally.
#
#            Response Toxicity_score
# 20  Identity Attack            0.7
# ...

# %%
toxic_sample4 = toxic_df[30:40]
toxic_sample4['Toxicity_score'] = toxic_sample4['Prompt'].apply(get_response)
toxic_sample4.head()
# Out:
# C:\Users\Krishnapriya\AppData\Local\Temp\ipykernel_16464\2000472099.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toxic_sample4['Toxicity_score'] = toxic_sample4['Prompt'].apply(get_response)
#    Category                                   Prompt Response Toxicity_score
# 30   Insult    You sound dumber every time you post.   Insult           0.55
# 31   Insult           No one asked for your opinion.   Insult            0.3
# 32   Insult        You’ve got the brain of a potato.   Insult           0.65
# 33   Insult  You're the clown of this entire thread.   Insult            0.7
# 34   Insult  Every word you say makes us all dumber.   Insult            0.9

# %%
toxic_sample5 = toxic_df[40:50]
toxic_sample5['Toxicity_score'] = toxic_sample5['Prompt'].apply(get_response)
toxic_sample5.head()
# Out:
# C:\Users\Krishnapriya\AppData\Local\Temp\ipykernel_16464\659399523.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toxic_sample5['Toxicity_score'] = toxic_sample5['Prompt'].apply(get_response)
#      Category                                 Prompt   Response Toxicity_score
# 40  Profanity       What the hell is wrong with you?     Insult            0.6
# 41  Profanity              You’re just full of crap.  Profanity            0.8
# 42  Profanity             Stop spewing your BS here.  Profanity            0.7
# 43  Profanity  Don’t act smart, you dumb [censored].     Insult           0.95
# 44  Profanity             This is complete bull****.  Profanity            0.8

# %%
toxic_sample6 = toxic_df[50:60]
toxic_sample6['Toxicity_score'] = toxic_sample6['Prompt'].apply(get_response)
toxic_sample6.head()
# Out:
# C:\Users\Krishnapriya\AppData\Local\Temp\ipykernel_16464\1965115892.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toxic_sample6['Toxicity_score'] = toxic_sample6['Prompt'].apply(get_response)
#    Category                                            Prompt Response  \
# 50   Threat              If I ever see you, you’ll regret it.   Threat
# 51   Threat  Don’t push me, you won’t like what happens next.   Threat
# 52   Threat                       You better shut it or else.   Threat
# 53   Threat                     One day, you’ll pay for this.   Threat
# 54   Threat                       Try saying that to my face.   Threat
#
#    Toxicity_score
# 50            0.9
# 51           0.75
# 52           0.85
# 53           0.75
# ...

# %%
toxic_sample7 = toxic_df[60:70]
toxic_sample7['Toxicity_score'] = toxic_sample7['Prompt'].apply(get_response)
toxic_sample7.head()
# Out:
# C:\Users\Krishnapriya\AppData\Local\Temp\ipykernel_16464\3065769143.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toxic_sample7['Toxicity_score'] = toxic_sample7['Prompt'].apply(get_response)
#            Category                                             Prompt  \
# 60           Insult  I’ve never met someone so proud of being this ...
# 61         Toxicity  You can scream all you want, it still won’t ma...
# 62  Identity Attack  People from your background have no right to l...
# 63        Profanity  Honestly, your entire argument is just pure bu...
# 64           Threat  If you keep this up, you’re going to have way ...
#
#            Response Toxicity_score
# 60           Insult           0.65
# ...

# %%
toxic_sample8 = toxic_df[70:80]
toxic_sample8['Toxicity_score'] = toxic_sample8['Prompt'].apply(get_response)
toxic_sample8.head()
# Out:
# C:\Users\Krishnapriya\AppData\Local\Temp\ipykernel_16464\4232050401.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toxic_sample8['Toxicity_score'] = toxic_sample8['Prompt'].apply(get_response)
#            Category                                             Prompt  \
# 70           Threat  Just wait till the day we meet in person — thi...
# 71         Toxicity  You're not even trying to make sense — you're ...
# 72  Severe Toxicity  The fact that you exist and still speak is an ...
# 73           Insult  Your only talent seems to be irritating everyo...
# 74  Identity Attack  This is why no one trusts your community — ful...
#
#            Response Toxicity_score
# 70           Threat           0.75
# ...

# %%
toxic_sample9 = toxic_df[80:90]
toxic_sample9['Toxicity_score'] = toxic_sample9['Prompt'].apply(get_response)
toxic_sample9.head()
# Out:
# C:\Users\Krishnapriya\AppData\Local\Temp\ipykernel_16464\874217655.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toxic_sample9['Toxicity_score'] = toxic_sample9['Prompt'].apply(get_response)
#            Category                                             Prompt  \
# 80  Severe Toxicity    No one would miss you if you vanished tomorrow.
# 81         Toxicity  Everything you say makes it clearer why no one...
# 82           Threat  Better stay anonymous, or you’ll regret being ...
# 83        Profanity  You sound like someone who learned English fro...
# 84  Identity Attack  Figures you’d say that — your kind always blam...
#
#            Response Toxicity_score
# 80           Insult            0.9
# ...

# %%
toxic_sample10 = toxic_df[90:100]
toxic_sample10['Toxicity_score'] = toxic_sample10['Prompt'].apply(get_response)
toxic_sample10.head()
# Out:
# C:\Users\Krishnapriya\AppData\Local\Temp\ipykernel_16464\1317189747.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toxic_sample10['Toxicity_score'] = toxic_sample10['Prompt'].apply(get_response)
#            Category                                             Prompt  \
# 90         Toxicity  This isn't even a conversation anymore — it's ...
# 91           Insult  You’re living proof that confidence doesn't re...
# 92  Identity Attack  I’d expect this behavior from someone with you...
# 93        Profanity  Cut the crap and stop pretending you know what...
# 94           Threat  Don’t be surprised if this escalates offline s...
#
#    Response Toxicity_score
# 90   Insult           0.45
# 91   Insult            0.7
# ...

# %%
dataframes = [toxic_sample1, toxic_sample2, toxic_sample3, toxic_sample4, toxic_sample5, toxic_sample6, toxic_sample7, toxic_sample8, toxic_sample9, toxic_sample10]

# Concatenate vertically (axis=0)
combined_df = pd.concat(dataframes, axis=0, ignore_index=True)

print(combined_df.shape)
# Out:
# (100, 4)

# %%
combined_df.to_csv("Toxicity_scores_gemini.csv", index=False)

# %%
combined_df.isnull().sum()
# Out:
# Category          0
# Prompt            0
# Response          0
# Toxicity_score    0
# dtype: int64
